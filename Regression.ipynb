# %%
import itertools

import pandas as pd
import numpy as np

import linearmodels

# %%
susb = (
    pd.read_csv('data/final/susb_combined.csv')
    .set_index(['initial_year', 'naics_code', 'var'])
    ['value']
    .unstack()
    .reset_index()
    .rename(columns={'initial_year': 'year'})
    .assign(empl_created=lambda df: df['empl_births'] + df['empl_expand'])
    .assign(empl_destroyed=lambda df: 0 - df['empl_deaths'] - df['empl_contract'])
)

dhs = pd.DataFrame({
    'year': susb['year'] + 1,
    'naics_code': susb['naics_code'],
    'estb_dhs': susb['estb_initial'] + (susb['estb_births'] - susb['estb_deaths']) / 2,
    'empl_dhs': susb['empl_initial'] + (susb['empl_created'] - susb['empl_destroyed']) / 2,
})

susb = (
    susb
    .merge(dhs, how='outer')
    .assign(estb_birth_rate=lambda df: 100 * df['estb_births'] / df['estb_dhs'])
    .assign(empl_create_rate=lambda df: 100 * df['empl_created'] / df['empl_dhs'])
    .assign(empl_destroy_rate=lambda df: 100 * df['empl_destroyed'] / df['empl_dhs'])
)

# %%
rd31_3digit = (
    pd.read_csv('data/rd31/cfr_naics07-3digit_extract.csv')
    .rename(columns={'industry-relevant restrictions': 'regdata31'})
    [['year', 'naics_code', 'regdata31']]
)

# %%
rd31_4digit = (
    pd.read_csv('data/rd31/cfr_naics07-4digit_extract.csv')
    .rename(columns={'industry-relevant restrictions': 'regdata31'})
    [['year', 'naics_code', 'regdata31']]
)

# %%
rd20_3digit = (
    pd.read_csv('data/rd20/three_digit_industry_RegData2_0.csv')
    .groupby(['year', 'industry_code'])['industry_regulation_index'].sum()
    .reset_index()
    .rename(columns={
        'industry_code': 'naics_code',
        'industry_regulation_index': 'regdata20'
    })
    .loc[lambda df: df['regdata20'] > 0]
)

# %% [raw]
# rd20_4digit = (
#     pd.read_csv('data/rd20/four_digit_industry_RegData2_0.csv')
#     .groupby(['year', 'industry_code'])['industry_regulation_index'].sum()
#     .reset_index()
#     .rename(columns={
#         'industry_code': 'naics_code',
#         'industry_regulation_index': 'regdata20'
#     })
#     .loc[lambda df: df['regdata20'] > 0]
# )

# %%
rd21_3digit = (
    pd.read_csv(
        'data/rd21/industry_classification_probabilities.csv',       
        index_col=['year', 'title', 'part']
    )
    .mul(
        (
            pd.read_csv(
                'data/rd21/cfrref.csv',
                index_col=['year', 'title', 'part'],
                encoding='latin-1'
            )
            ['restrictions']
        ),
        axis=0
    )
    .groupby(level='year').sum()
    .reset_index()
    .melt(id_vars='year', var_name='naics_code', value_name='regdata21')
    .assign(naics_code=lambda df: df['naics_code'].astype(int))
)

# %%
rd22_3digit = (
    pd.read_csv(
        'data/rd22/RegData_2_2_by_3-digit_industry.csv',
        names=['year', 'naics_code', 'restrictions', 'words'],
        skiprows=1,
    )
    .rename(columns={'restrictions': 'regdata22'})
    [['year', 'naics_code', 'regdata22']]
)

# %%
rd22_4digit = (
    pd.read_csv(
        'data/rd22/RegData_2_2_by_4-digit_industry.csv',
        names=['year', 'naics_code', 'restrictions', 'words'],
        skiprows=1
    )
    .rename(columns={'restrictions': 'regdata22'})
    [['year', 'naics_code', 'regdata22']]
)

# %%
combined_3digit = (
    susb[
        (susb['naics_code'] >= 100)
        & (susb['naics_code'] < 814)
    ]
    .assign(estb_births=lambda df: df[df['estb_births'] > 0]['estb_births'])
    .assign(estb_deaths=lambda df: df[df['estb_deaths'] > 0]['estb_deaths'])
    .assign(empl_created=lambda df: df[df['empl_created'] > 0]['empl_created'])
    .merge(rd20_3digit, how='left')
    .merge(rd21_3digit, how='left')
    .merge(rd22_3digit, how='left')
    .merge(rd31_3digit, how='left')
)
combined_4digit = (
    susb[
        (susb['naics_code'] >= 1000)
        & (susb['naics_code'] < 8140)
    ]
    .assign(estb_births=lambda df: df[df['estb_births'] > 0]['estb_births'])
    .assign(estb_deaths=lambda df: df[df['estb_deaths'] > 0]['estb_deaths'])
    .assign(empl_created=lambda df: df[df['empl_created'] > 0]['empl_created'])
    .merge(rd20_4digit, how='left')
    .merge(rd22_4digit, how='left')
    .merge(rd31_4digit, how='left')
)

# %%
summary_table_rows = {
    'estb_birth_rate': 'Startup Rate',
    'empl_create_rate': 'Job Creation Rate',
    'empl_destroy_rate': 'Job Destruction Rate',
    'estb_births': 'Establishment Births',
    'estb_deaths': 'Establishment Deaths',
    'empl_created': 'New Hires',
    'regdata20': 'RegData 2.0 Regulation Index',
    'regdata21': 'RegData 2.1 Regulation Index',
    'regdata22': 'RegData 2.2 Regulation Index',
    'regdata31': 'RegData 3.1 Regulation Index'
}

(
    combined_3digit
    .loc[lambda df: df['year'] <= 2010]
    .describe()
    [[i for i in summary_table_rows if i in combined_3digit]]
    .round(2)
    .rename(columns=summary_table_rows)
    .T
    [['count', 'mean', 'std', 'min', 'max']]
    .rename(columns={'std':'standard deviation'})
    .assign(count=lambda df: df['count'].astype(int))
    .applymap(lambda x: f'{x:,.0f}' if x > 100 else f'{x:.02f}')
)
# Out:
#                               count     mean standard deviation    min  \
# Startup Rate                  1,030    10.84               4.83   1.05
# Job Creation Rate               970    14.58               6.65   1.35
# Job Destruction Rate            969    15.11               5.33   0.94
# Establishment Births          1,118    8,422             14,666   1.00
# Establishment Deaths          1,116    8,110             13,526   1.00
# New Hires                     1,075  209,215            333,911    746
# RegData 2.0 Regulation Index    869    5,480             10,007   0.36
# RegData 2.1 Regulation Index    975   32,585             28,725  4,387
# RegData 2.2 Regulation Index    650    8,717             13,006  21.12
# RegData 3.1 Regulation Index    650   16,644             20,416    233
#
#                                     max
# Startup Rate                      46.15
# Job Creation Rate                 81.29
# Job Destruction Rate              61.84
# Establishment Births            105,010
# Establishment Deaths             94,476
# New Hires                     2,297,342
# RegData 2.0 Regulation Index     63,506
# RegData 2.1 Regulation Index    143,593
# RegData 2.2 Regulation Index     66,351
# RegData 3.1 Regulation Index     97,502

# %%
(
    combined_4digit.describe()
    [[i for i in summary_table_rows if i in combined_4digit]]
    .round(2)
    .rename(columns=summary_table_rows)
    .T
    [['count', 'mean', 'std', 'min', 'max']]
    .rename(columns={'std':'standard deviation'})
    .assign(count=lambda df: df['count'].astype(int))
    .applymap(lambda x: f'{x:,.0f}' if x > 100 else f'{x:.02f}')
)
# Out:
#                               count    mean standard deviation   min  \
# Startup Rate                  4,056   10.58               8.05  0.00
# Job Creation Rate             3,658   14.57               6.80  1.35
# Job Destruction Rate          3,645   14.78               5.75  0.94
# Establishment Births          4,637   2,482              4,423  1.00
# Establishment Deaths          4,636   2,353              4,090  1.00
# New Hires                     4,377  61,888            115,468   162
# RegData 2.0 Regulation Index  2,956   1,124              3,935  0.00
# RegData 2.2 Regulation Index  1,632   2,778              3,970  8.61
# RegData 3.1 Regulation Index  2,142  10,226             16,530   149
#
#                                     max
# Startup Rate                        370
# Job Creation Rate                 84.67
# Job Destruction Rate              81.63
# Establishment Births             38,742
# Establishment Deaths             40,944
# New Hires                     1,396,593
# RegData 2.0 Regulation Index     36,131
# RegData 2.2 Regulation Index     25,482
# RegData 3.1 Regulation Index     84,274

# %% [markdown]
# # Regressions

# %%
def get_model(dep, ind, data, logdep=True, cluster=False):
    safe_data = (
        data
        [[dep, ind, 'naics_code', 'year']]
        .dropna()
        .set_index(['naics_code', 'year'])
    )
    if logdep:
        formula = f'np.log({dep}) ~ 1 + np.log({ind}) + EntityEffects + TimeEffects'
    else:
        formula = f'{dep} ~ 1 + np.log({ind})'
    print(formula)
    model = linearmodels.PanelOLS.from_formula(formula, data=safe_data)
    if cluster:
        fitted = model.fit(cov_type='clustered', cluster_entity=True)
    else:
        fitted = model.fit(cov_type='robust')
    print(fitted.summary)
    return (
        fitted.params[1],
        fitted.std_errors[1],
        fitted.pvalues[1]
    )

# %%
DIGITS = (
    (3, combined_3digit),
    (4, combined_4digit)
)

INDVARS = (
    'regdata20',
    'regdata21',
    'regdata22',
    'regdata31',
)

DEPVARS = (
    ('estb_births', True), # Variable, Log
    ('estb_deaths', True),
    ('empl_created', True),
    ('estb_birth_rate', False),
    ('empl_create_rate', False),
    ('empl_destroy_rate', False)
)

CLUSTER = (True, False)

# %%
results = []
for (digits, data), indvar, (depvar, logdep), cluster in itertools.product(DIGITS, INDVARS, DEPVARS, CLUSTER):
    if not indvar in data:
        continue
    param, stderr, pval = get_model(depvar, indvar, data, logdep, cluster)
    results.append([digits, depvar, indvar, param, stderr, pval, 'clustered' if cluster else 'robust'])
results = pd.DataFrame(results, columns=['digits', 'depvar', 'indvar', 'param', 'stderr', 'pval', 'errtype'])
# Out:
# np.log(estb_births) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_births)   R-squared:                        0.0025
# Estimator:                    PanelOLS   R-squared (Between):              0.0040
# No. Observations:                  936   R-squared (Within):               0.0065
# Date:                 Tue, Jun 11 2019   R-squared (Overall):              0.0030
# Time:                         17:13:03   Log-likelihood                    47.611
# Cov. Estimator:              Clustered
#                                          F-statistic:                      2.1099
# Entities:                           67   P-value                           0.1467
# Avg Obs:                        13.970   Distribution:                   F(1,855)
# Min Obs:                        12.000
# Max Obs:                        14.000   F-statistic (robust):             0.5199
#                                          P-value                           0.4711
# Time periods:                       14   Distribution:                   F(1,855)
# Avg Obs:                        66.857
# Min Obs:                        66.000
# Max Obs:                        67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.0225     0.5770     13.905     0.0000      6.8901      9.1549
# np.log(regdata20)    -0.0623     0.0863    -0.7211     0.4711     -0.2317      0.1072
# =====================================================================================
#
# F-test for Poolability: 672.65
# P-value: 0.0000
# Distribution: F(79,855)
#
# Included effects: Entity, Time
# np.log(estb_births) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_births)   R-squared:                        0.0025
# Estimator:                    PanelOLS   R-squared (Between):              0.0040
# No. Observations:                  936   R-squared (Within):               0.0065
# Date:                 Tue, Jun 11 2019   R-squared (Overall):              0.0030
# Time:                         17:13:03   Log-likelihood                    47.611
# Cov. Estimator:                 Robust
#                                          F-statistic:                      2.1099
# Entities:                           67   P-value                           0.1467
# Avg Obs:                        13.970   Distribution:                   F(1,855)
# Min Obs:                        12.000
# Max Obs:                        14.000   F-statistic (robust):             1.8912
#                                          P-value                           0.1694
# Time periods:                       14   Distribution:                   F(1,855)
# Avg Obs:                        66.857
# Min Obs:                        66.000
# Max Obs:                        67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.0225     0.3025     26.524     0.0000      7.4288      8.6162
# np.log(regdata20)    -0.0623     0.0453    -1.3752     0.1694     -0.1511      0.0266
# =====================================================================================
#
# F-test for Poolability: 672.65
# P-value: 0.0000
# Distribution: F(79,855)
#
# Included effects: Entity, Time
# np.log(estb_deaths) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_deaths)   R-squared:                        0.0047
# Estimator:                    PanelOLS   R-squared (Between):              0.0071
# No. Observations:                  934   R-squared (Within):               0.0070
# Date:                 Tue, Jun 11 2019   R-squared (Overall):              0.0065
# Time:                         17:13:04   Log-likelihood                    121.99
# Cov. Estimator:              Clustered
#                                          F-statistic:                      4.0096
# Entities:                           67   P-value                           0.0456
# Avg Obs:                        13.940   Distribution:                   F(1,853)
# Min Obs:                        12.000
# Max Obs:                        14.000   F-statistic (robust):             0.5599
#                                          P-value                           0.4545
# Time periods:                       14   Distribution:                   F(1,853)
# Avg Obs:                        66.714
# Min Obs:                        65.000
# Max Obs:                        67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.1543     0.7084     11.511     0.0000      6.7639      9.5447
# np.log(regdata20)    -0.0793     0.1060    -0.7482     0.4545     -0.2873      0.1287
# =====================================================================================
#
# F-test for Poolability: 782.20
# P-value: 0.0000
# Distribution: F(79,853)
#
# Included effects: Entity, Time
# np.log(estb_deaths) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_deaths)   R-squared:                        0.0047
# Estimator:                    PanelOLS   R-squared (Between):              0.0071
# No. Observations:                  934   R-squared (Within):               0.0070
# Date:                 Tue, Jun 11 2019   R-squared (Overall):              0.0065
# Time:                         17:13:04   Log-likelihood                    121.99
# Cov. Estimator:                 Robust
#                                          F-statistic:                      4.0096
# Entities:                           67   P-value                           0.0456
# Avg Obs:                        13.940   Distribution:                   F(1,853)
# Min Obs:                        12.000
# Max Obs:                        14.000   F-statistic (robust):             2.9201
#                                          P-value                           0.0878
# Time periods:                       14   Distribution:                   F(1,853)
# Avg Obs:                        66.714
# Min Obs:                        65.000
# Max Obs:                        67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.1543     0.3105     26.258     0.0000      7.5448      8.7638
# np.log(regdata20)    -0.0793     0.0464    -1.7088     0.0878     -0.1704      0.0118
# =====================================================================================
#
# F-test for Poolability: 782.20
# P-value: 0.0000
# Distribution: F(79,853)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0292
# Estimator:                     PanelOLS   R-squared (Between):             -0.0730
# No. Observations:                   894   R-squared (Within):               0.0497
# Date:                  Tue, Jun 11 2019   R-squared (Overall):             -0.0999
# Time:                          17:13:04   Log-likelihood                    96.991
# Cov. Estimator:               Clustered
#                                           F-statistic:                      24.463
# Entities:                            67   P-value                           0.0000
# Avg Obs:                         13.343   Distribution:                   F(1,813)
# Min Obs:                         2.0000
# Max Obs:                         14.000   F-statistic (robust):             2.5796
#                                           P-value                           0.1086
# Time periods:                        14   Distribution:                   F(1,813)
# Avg Obs:                         63.857
# Min Obs:                         61.000
# Max Obs:                         67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             12.628     0.8512     14.836     0.0000      10.957      14.298
# np.log(regdata20)    -0.2059     0.1282    -1.6061     0.1086     -0.4576      0.0457
# =====================================================================================
#
# F-test for Poolability: 471.70
# P-value: 0.0000
# Distribution: F(79,813)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0292
# Estimator:                     PanelOLS   R-squared (Between):             -0.0730
# No. Observations:                   894   R-squared (Within):               0.0497
# Date:                  Tue, Jun 11 2019   R-squared (Overall):             -0.0999
# Time:                          17:13:04   Log-likelihood                    96.991
# Cov. Estimator:                  Robust
#                                           F-statistic:                      24.463
# Entities:                            67   P-value                           0.0000
# Avg Obs:                         13.343   Distribution:                   F(1,813)
# Min Obs:                         2.0000
# Max Obs:                         14.000   F-statistic (robust):             17.182
#                                           P-value                           0.0000
# Time periods:                        14   Distribution:                   F(1,813)
# Avg Obs:                         63.857
# Min Obs:                         61.000
# Max Obs:                         67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             12.628     0.3300     38.266     0.0000      11.980      13.275
# np.log(regdata20)    -0.2059     0.0497    -4.1452     0.0000     -0.3035     -0.1084
# =====================================================================================
#
# F-test for Poolability: 471.70
# P-value: 0.0000
# Distribution: F(79,813)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata20)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0110
# Estimator:                   PanelOLS   R-squared (Between):              0.0168
# No. Observations:                 868   R-squared (Within):              -0.0016
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0110
# Time:                        17:13:04   Log-likelihood                   -2619.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      9.6260
# Entities:                          67   P-value                           0.0020
# Avg Obs:                       12.955   Distribution:                   F(1,866)
# Min Obs:                       11.000
# Max Obs:                       13.000   F-statistic (robust):             1.2697
#                                         P-value                           0.2601
# Time periods:                      13   Distribution:                   F(1,866)
# Avg Obs:                       66.769
# Min Obs:                       65.000
# Max Obs:                       67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             9.2632     1.2854     7.2067     0.0000      6.7404      11.786
# np.log(regdata20)     0.2098     0.1862     1.1268     0.2601     -0.1556      0.5752
# =====================================================================================
#
#
# estb_birth_rate ~ 1 + np.log(regdata20)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0110
# Estimator:                   PanelOLS   R-squared (Between):              0.0168
# No. Observations:                 868   R-squared (Within):              -0.0016
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0110
# Time:                        17:13:04   Log-likelihood                   -2619.7
# Cov. Estimator:                Robust
#                                         F-statistic:                      9.6260
# Entities:                          67   P-value                           0.0020
# Avg Obs:                       12.955   Distribution:                   F(1,866)
# Min Obs:                       11.000
# Max Obs:                       13.000   F-statistic (robust):             10.807
#                                         P-value                           0.0011
# Time periods:                      13   Distribution:                   F(1,866)
# Avg Obs:                       66.769
# Min Obs:                       65.000
# Max Obs:                       67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             9.2632     0.4539     20.407     0.0000      8.3723      10.154
# np.log(regdata20)     0.2098     0.0638     3.2874     0.0011      0.0845      0.3350
# =====================================================================================
#
#
# empl_create_rate ~ 1 + np.log(regdata20)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):             -0.0011
# No. Observations:                 811   R-squared (Within):               0.0005
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0003
# Time:                        17:13:04   Log-likelihood                   -2671.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.2790
# Entities:                          66   P-value                           0.5975
# Avg Obs:                       12.288   Distribution:                   F(1,809)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             0.0336
#                                         P-value                           0.8545
# Time periods:                      13   Distribution:                   F(1,809)
# Avg Obs:                       62.385
# Min Obs:                       61.000
# Max Obs:                       65.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             14.373     1.7731     8.1062     0.0000      10.893      17.854
# np.log(regdata20)    -0.0481     0.2622    -0.1834     0.8545     -0.5628      0.4666
# =====================================================================================
#
#
# empl_create_rate ~ 1 + np.log(regdata20)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):             -0.0011
# No. Observations:                 811   R-squared (Within):               0.0005
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0003
# Time:                        17:13:04   Log-likelihood                   -2671.8
# Cov. Estimator:                Robust
#                                         F-statistic:                      0.2790
# Entities:                          66   P-value                           0.5975
# Avg Obs:                       12.288   Distribution:                   F(1,809)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             0.2377
#                                         P-value                           0.6260
# Time periods:                      13   Distribution:                   F(1,809)
# Avg Obs:                       62.385
# Min Obs:                       61.000
# Max Obs:                       65.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             14.373     0.6530     22.011     0.0000      13.091      15.655
# np.log(regdata20)    -0.0481     0.0986    -0.4876     0.6260     -0.2417      0.1455
# =====================================================================================
#
#
# empl_destroy_rate ~ 1 + np.log(regdata20)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:      empl_destroy_rate   R-squared:                        0.0044
# Estimator:                   PanelOLS   R-squared (Between):             -0.0018
# No. Observations:                 808   R-squared (Within):               0.0015
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0044
# Time:                        17:13:05   Log-likelihood                   -2505.0
# Cov. Estimator:             Clustered
#                                         F-statistic:                      3.5502
# Entities:                          66   P-value                           0.0599
# Avg Obs:                       12.242   Distribution:                   F(1,806)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             0.4646
#                                         P-value                           0.4957
# Time periods:                      13   Distribution:                   F(1,806)
# Avg Obs:                       62.154
# Min Obs:                       60.000
# Max Obs:                       66.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             15.639     1.3252     11.801     0.0000      13.038      18.241
# np.log(regdata20)    -0.1415     0.2076    -0.6816     0.4957     -0.5490      0.2660
# =====================================================================================
#
#
# empl_destroy_rate ~ 1 + np.log(regdata20)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:      empl_destroy_rate   R-squared:                        0.0044
# Estimator:                   PanelOLS   R-squared (Between):             -0.0018
# No. Observations:                 808   R-squared (Within):               0.0015
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0044
# Time:                        17:13:05   Log-likelihood                   -2505.0
# Cov. Estimator:                Robust
#                                         F-statistic:                      3.5502
# Entities:                          66   P-value                           0.0599
# Avg Obs:                       12.242   Distribution:                   F(1,806)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             3.3038
#                                         P-value                           0.0695
# Time periods:                      13   Distribution:                   F(1,806)
# Avg Obs:                       62.154
# Min Obs:                       60.000
# Max Obs:                       66.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             15.639     0.5135     30.453     0.0000      14.631      16.647
# np.log(regdata20)    -0.1415     0.0778    -1.8176     0.0695     -0.2943      0.0113
# =====================================================================================
#
#
# np.log(estb_births) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_births)   R-squared:                        0.0188
# Estimator:                    PanelOLS   R-squared (Between):             -0.0923
# No. Observations:                 1125   R-squared (Within):               0.0681
# Date:                 Tue, Jun 11 2019   R-squared (Overall):             -0.0886
# Time:                         17:13:05   Log-likelihood                    118.80
# Cov. Estimator:              Clustered
#                                          F-statistic:                      19.789
# Entities:                           75   P-value                           0.0000
# Avg Obs:                        15.000   Distribution:                  F(1,1035)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             5.1235
#                                          P-value                           0.0238
# Time periods:                       15   Distribution:                  F(1,1035)
# Avg Obs:                        75.000
# Min Obs:                        75.000
# Max Obs:                        75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             11.068     1.4118     7.8392     0.0000      8.2972      13.838
# np.log(regdata21)    -0.3168     0.1400    -2.2635     0.0238     -0.5914     -0.0422
# =====================================================================================
#
# F-test for Poolability: 597.31
# P-value: 0.0000
# Distribution: F(88,1035)
#
# Included effects: Entity, Time
# np.log(estb_births) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_births)   R-squared:                        0.0188
# Estimator:                    PanelOLS   R-squared (Between):             -0.0923
# No. Observations:                 1125   R-squared (Within):               0.0681
# Date:                 Tue, Jun 11 2019   R-squared (Overall):             -0.0886
# Time:                         17:13:05   Log-likelihood                    118.80
# Cov. Estimator:                 Robust
#                                          F-statistic:                      19.789
# Entities:                           75   P-value                           0.0000
# Avg Obs:                        15.000   Distribution:                  F(1,1035)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             14.915
#                                          P-value                           0.0001
# Time periods:                       15   Distribution:                  F(1,1035)
# Avg Obs:                        75.000
# Min Obs:                        75.000
# Max Obs:                        75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             11.068     0.8273     13.377     0.0000      9.4441      12.691
# np.log(regdata21)    -0.3168     0.0820    -3.8621     0.0001     -0.4778     -0.1558
# =====================================================================================
#
# F-test for Poolability: 597.31
# P-value: 0.0000
# Distribution: F(88,1035)
#
# Included effects: Entity, Time
# np.log(estb_deaths) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_deaths)   R-squared:                        0.0110
# Estimator:                    PanelOLS   R-squared (Between):             -0.0641
# No. Observations:                 1125   R-squared (Within):               0.0391
# Date:                 Tue, Jun 11 2019   R-squared (Overall):             -0.0618
# Time:                         17:13:05   Log-likelihood                    98.153
# Cov. Estimator:              Clustered
#                                          F-statistic:                      11.476
# Entities:                           75   P-value                           0.0007
# Avg Obs:                        15.000   Distribution:                  F(1,1035)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             2.0745
#                                          P-value                           0.1501
# Time periods:                       15   Distribution:                  F(1,1035)
# Avg Obs:                        75.000
# Min Obs:                        75.000
# Max Obs:                        75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             10.347     1.7209     6.0125     0.0000      6.9700      13.724
# np.log(regdata21)    -0.2457     0.1706    -1.4403     0.1501     -0.5805      0.0890
# =====================================================================================
#
# F-test for Poolability: 564.66
# P-value: 0.0000
# Distribution: F(88,1035)
#
# Included effects: Entity, Time
# np.log(estb_deaths) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_deaths)   R-squared:                        0.0110
# Estimator:                    PanelOLS   R-squared (Between):             -0.0641
# No. Observations:                 1125   R-squared (Within):               0.0391
# Date:                 Tue, Jun 11 2019   R-squared (Overall):             -0.0618
# Time:                         17:13:06   Log-likelihood                    98.153
# Cov. Estimator:                 Robust
#                                          F-statistic:                      11.476
# Entities:                           75   P-value                           0.0007
# Avg Obs:                        15.000   Distribution:                  F(1,1035)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             6.3132
#                                          P-value                           0.0121
# Time periods:                       15   Distribution:                  F(1,1035)
# Avg Obs:                        75.000
# Min Obs:                        75.000
# Max Obs:                        75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             10.347     0.9863     10.491     0.0000      8.4115      12.282
# np.log(regdata21)    -0.2457     0.0978    -2.5126     0.0121     -0.4376     -0.0538
# =====================================================================================
#
# F-test for Poolability: 564.66
# P-value: 0.0000
# Distribution: F(88,1035)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0392
# Estimator:                     PanelOLS   R-squared (Between):             -0.2233
# No. Observations:                  1093   R-squared (Within):               0.1291
# Date:                  Tue, Jun 11 2019   R-squared (Overall):             -0.2258
# Time:                          17:13:06   Log-likelihood                   -14.461
# Cov. Estimator:               Clustered
#                                           F-statistic:                      40.971
# Entities:                            75   P-value                           0.0000
# Avg Obs:                         14.573   Distribution:                  F(1,1003)
# Min Obs:                         5.0000
# Max Obs:                         15.000   F-statistic (robust):             8.9371
#                                           P-value                           0.0029
# Time periods:                        15   Distribution:                  F(1,1003)
# Avg Obs:                         72.867
# Min Obs:                         70.000
# Max Obs:                         75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             16.665     1.7552     9.4947     0.0000      13.221      20.109
# np.log(regdata21)    -0.5199     0.1739    -2.9895     0.0029     -0.8612     -0.1786
# =====================================================================================
#
# F-test for Poolability: 320.51
# P-value: 0.0000
# Distribution: F(88,1003)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0392
# Estimator:                     PanelOLS   R-squared (Between):             -0.2233
# No. Observations:                  1093   R-squared (Within):               0.1291
# Date:                  Tue, Jun 11 2019   R-squared (Overall):             -0.2258
# Time:                          17:13:06   Log-likelihood                   -14.461
# Cov. Estimator:                  Robust
#                                           F-statistic:                      40.971
# Entities:                            75   P-value                           0.0000
# Avg Obs:                         14.573   Distribution:                  F(1,1003)
# Min Obs:                         5.0000
# Max Obs:                         15.000   F-statistic (robust):             25.106
#                                           P-value                           0.0000
# Time periods:                        15   Distribution:                  F(1,1003)
# Avg Obs:                         72.867
# Min Obs:                         70.000
# Max Obs:                         75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             16.665     1.0474     15.910     0.0000      14.610      18.720
# np.log(regdata21)    -0.5199     0.1038    -5.0106     0.0000     -0.7235     -0.3163
# =====================================================================================
#
# F-test for Poolability: 320.51
# P-value: 0.0000
# Distribution: F(88,1003)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata21)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):             -0.0001
# No. Observations:                 975   R-squared (Within):               0.0010
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0003
# Time:                        17:13:06   Log-likelihood                   -2896.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.2488
# Entities:                          75   P-value                           0.6180
# Avg Obs:                       13.000   Distribution:                   F(1,973)
# Min Obs:                       13.000
# Max Obs:                       13.000   F-statistic (robust):             0.0314
#                                         P-value                           0.8594
# Time periods:                      13   Distribution:                   F(1,973)
# Avg Obs:                       75.000
# Min Obs:                       75.000
# Max Obs:                       75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             11.659     5.2680     2.2131     0.0271      1.3206      21.997
# np.log(regdata21)    -0.0933     0.5266    -0.1772     0.8594     -1.1267      0.9401
# =====================================================================================
#
#
# estb_birth_rate ~ 1 + np.log(regdata21)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0003
# Estimator:                   PanelOLS   R-squared (Between):             -0.0001
# No. Observations:                 975   R-squared (Within):               0.0010
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0003
# Time:                        17:13:06   Log-likelihood                   -2896.8
# Cov. Estimator:                Robust
#                                         F-statistic:                      0.2488
# Entities:                          75   P-value                           0.6180
# Avg Obs:                       13.000   Distribution:                   F(1,973)
# Min Obs:                       13.000
# Max Obs:                       13.000   F-statistic (robust):             0.2819
#                                         P-value                           0.5956
# Time periods:                      13   Distribution:                   F(1,973)
# Avg Obs:                       75.000
# Min Obs:                       75.000
# Max Obs:                       75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             11.659     1.7692     6.5897     0.0000      8.1867      15.131
# np.log(regdata21)    -0.0933     0.1758    -0.5309     0.5956     -0.4383      0.2516
# =====================================================================================
#
#
# empl_create_rate ~ 1 + np.log(regdata21)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):              0.0002
# No. Observations:                 929   R-squared (Within):              -0.0007
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0002
# Time:                        17:13:06   Log-likelihood                   -3036.5
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.1393
# Entities:                          75   P-value                           0.7091
# Avg Obs:                       12.387   Distribution:                   F(1,927)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             0.0198
#                                         P-value                           0.8881
# Time periods:                      13   Distribution:                   F(1,927)
# Avg Obs:                       71.462
# Min Obs:                       68.000
# Max Obs:                       74.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             13.176     6.8715     1.9175     0.0555     -0.3096      26.661
# np.log(regdata21)     0.0961     0.6831     0.1407     0.8881     -1.2445      1.4367
# =====================================================================================
#
#
# empl_create_rate ~ 1 + np.log(regdata21)
#                           PanelOLS Estimation Summary
# ================================================================================
# ...
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.9129     1.1145     7.9976     0.0000      6.7270      11.099
# np.log(regdata31)     0.1360     0.1366     0.9959     0.3195     -0.1319      0.4038
# =====================================================================================
#
# F-test for Poolability: 189.26
# P-value: 0.0000
# Distribution: F(133,1626)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata31) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0040
# Estimator:                     PanelOLS   R-squared (Between):             -0.0345
# No. Observations:                  1761   R-squared (Within):              -0.0205
# Date:                  Tue, Jun 11 2019   R-squared (Overall):             -0.0323
# Time:                          17:13:15   Log-likelihood                   -659.56
# Cov. Estimator:                  Robust
#                                           F-statistic:                      6.4807
# Entities:                           119   P-value                           0.0110
# Avg Obs:                         14.798   Distribution:                  F(1,1626)
# Min Obs:                         1.0000
# Max Obs:                         16.000   F-statistic (robust):             5.7605
#                                           P-value                           0.0165
# Time periods:                        16   Distribution:                  F(1,1626)
# Avg Obs:                         110.06
# Min Obs:                         102.00
# Max Obs:                         117.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.9129     0.4636     19.223     0.0000      8.0035      9.8223
# np.log(regdata31)     0.1360     0.0567     2.4001     0.0165      0.0249      0.2471
# =====================================================================================
#
# F-test for Poolability: 189.26
# P-value: 0.0000
# Distribution: F(133,1626)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata31)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0024
# Estimator:                   PanelOLS   R-squared (Between):              0.0074
# No. Observations:                1662   R-squared (Within):               0.0010
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0024
# Time:                        17:13:15   Log-likelihood                   -6349.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      4.0380
# Entities:                         119   P-value                           0.0446
# Avg Obs:                       13.966   Distribution:                  F(1,1660)
# Min Obs:                       12.000
# Max Obs:                       14.000   F-statistic (robust):             1.4745
#                                         P-value                           0.2248
# Time periods:                      14   Distribution:                  F(1,1660)
# Avg Obs:                       118.71
# Min Obs:                       117.00
# Max Obs:                       119.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             13.452     2.7973     4.8089     0.0000      7.9654      18.939
# np.log(regdata31)    -0.3717     0.3061    -1.2143     0.2248     -0.9722      0.2287
# =====================================================================================
#
#
# estb_birth_rate ~ 1 + np.log(regdata31)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0024
# Estimator:                   PanelOLS   R-squared (Between):              0.0074
# No. Observations:                1662   R-squared (Within):               0.0010
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0024
# Time:                        17:13:15   Log-likelihood                   -6349.4
# Cov. Estimator:                Robust
#                                         F-statistic:                      4.0380
# Entities:                         119   P-value                           0.0446
# Avg Obs:                       13.966   Distribution:                  F(1,1660)
# Min Obs:                       12.000
# Max Obs:                       14.000   F-statistic (robust):             5.8086
#                                         P-value                           0.0161
# Time periods:                      14   Distribution:                  F(1,1660)
# Avg Obs:                       118.71
# Min Obs:                       117.00
# Max Obs:                       119.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             13.452     1.4781     9.1012     0.0000      10.553      16.351
# np.log(regdata31)    -0.3717     0.1542    -2.4101     0.0161     -0.6743     -0.0692
# =====================================================================================
#
#
# empl_create_rate ~ 1 + np.log(regdata31)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0100
# Estimator:                   PanelOLS   R-squared (Between):              0.0144
# No. Observations:                1469   R-squared (Within):               0.0055
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0100
# Time:                        17:13:16   Log-likelihood                   -4994.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      14.878
# Entities:                         116   P-value                           0.0001
# Avg Obs:                       12.664   Distribution:                  F(1,1467)
# Min Obs:                       1.0000
# Max Obs:                       14.000   F-statistic (robust):             2.1520
#                                         P-value                           0.1426
# Time periods:                      14   Distribution:                  F(1,1467)
# Avg Obs:                       104.93
# Min Obs:                       94.000
# Max Obs:                       112.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             17.871     2.8568     6.2555     0.0000      12.267      23.475
# np.log(regdata31)    -0.4935     0.3364    -1.4670     0.1426     -1.1533      0.1664
# =====================================================================================
#
#
# empl_create_rate ~ 1 + np.log(regdata31)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0100
# Estimator:                   PanelOLS   R-squared (Between):              0.0144
# No. Observations:                1469   R-squared (Within):               0.0055
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0100
# Time:                        17:13:16   Log-likelihood                   -4994.7
# Cov. Estimator:                Robust
#                                         F-statistic:                      14.878
# Entities:                         116   P-value                           0.0001
# Avg Obs:                       12.664   Distribution:                  F(1,1467)
# Min Obs:                       1.0000
# Max Obs:                       14.000   F-statistic (robust):             18.565
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                  F(1,1467)
# Avg Obs:                       104.93
# Min Obs:                       94.000
# Max Obs:                       112.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             17.871     0.9834     18.172     0.0000      15.942      19.800
# np.log(regdata31)    -0.4935     0.1145    -4.3088     0.0000     -0.7181     -0.2688
# =====================================================================================
#
#
# empl_destroy_rate ~ 1 + np.log(regdata31)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:      empl_destroy_rate   R-squared:                        0.0166
# Estimator:                   PanelOLS   R-squared (Between):              0.0332
# No. Observations:                1462   R-squared (Within):               0.0091
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0166
# Time:                        17:13:16   Log-likelihood                   -4801.7
# Cov. Estimator:             Clustered
#                                         F-statistic:                      24.655
# Entities:                         116   P-value                           0.0000
# Avg Obs:                       12.603   Distribution:                  F(1,1460)
# Min Obs:                       1.0000
# Max Obs:                       14.000   F-statistic (robust):             5.3432
#                                         P-value                           0.0209
# Time periods:                      14   Distribution:                  F(1,1460)
# Avg Obs:                       104.43
# Min Obs:                       94.000
# Max Obs:                       112.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             18.941     2.0498     9.2402     0.0000      14.920      22.962
# np.log(regdata31)    -0.5708     0.2469    -2.3115     0.0209     -1.0551     -0.0864
# =====================================================================================
#
#
# empl_destroy_rate ~ 1 + np.log(regdata31)
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:      empl_destroy_rate   R-squared:                        0.0166
# Estimator:                   PanelOLS   R-squared (Between):              0.0332
# No. Observations:                1462   R-squared (Within):               0.0091
# Date:                Tue, Jun 11 2019   R-squared (Overall):              0.0166
# Time:                        17:13:16   Log-likelihood                   -4801.7
# Cov. Estimator:                Robust
#                                         F-statistic:                      24.655
# Entities:                         116   P-value                           0.0000
# Avg Obs:                       12.603   Distribution:                  F(1,1460)
# Min Obs:                       1.0000
# Max Obs:                       14.000   F-statistic (robust):             34.231
#                                         P-value                           0.0000
# Time periods:                      14   Distribution:                  F(1,1460)
# Avg Obs:                       104.43
# Min Obs:                       94.000
# Max Obs:                       112.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             18.941     0.8322     22.761     0.0000      17.309      20.573
# np.log(regdata31)    -0.5708     0.0976    -5.8507     0.0000     -0.7621     -0.3794
# =====================================================================================

# %%
def format_row(row):
    return (
        f'{row["param"]:01.02f} '
        f'({row["pval"]:01.02f})'
        f'{"*" if row["pval"] < 0.1 else ""}'
        f'{"*" if row["pval"] < 0.05 else ""}'
        f'{"*" if row["pval"] < 0.01 else ""}'
    )

(
    results
    .set_index(['errtype', 'indvar', 'digits', 'depvar'])
    .apply(format_row, axis=1)
    .unstack()
    .sort_index()
    [['estb_births', 'estb_deaths', 'empl_created', 'estb_birth_rate', 'empl_create_rate', 'empl_destroy_rate']]
).xs('clustered')
# Out:
# depvar               estb_births   estb_deaths     empl_created  \
# indvar    digits
# regdata20 3         -0.06 (0.47)  -0.08 (0.45)     -0.21 (0.11)
#           4         -0.02 (0.20)  -0.01 (0.68)  -0.06 (0.01)***
# regdata21 3       -0.32 (0.02)**  -0.25 (0.15)  -0.52 (0.00)***
# regdata22 3          0.05 (0.53)   0.07 (0.31)      0.01 (0.90)
#           4        -0.16 (0.06)*  -0.10 (0.17)   -0.11 (0.03)**
# regdata31 3         -0.19 (0.31)  -0.22 (0.25)     -0.27 (0.13)
#           4          0.18 (0.15)   0.11 (0.33)      0.14 (0.32)
#
# depvar           estb_birth_rate empl_create_rate empl_destroy_rate
# indvar    digits
# regdata20 3          0.21 (0.26)     -0.05 (0.85)      -0.14 (0.50)
#           4          0.13 (0.31)      0.01 (0.92)      -0.13 (0.10)
# regdata21 3         -0.09 (0.86)      0.10 (0.89)      -0.77 (0.21)
# regdata22 3          0.08 (0.79)      0.44 (0.25)       0.07 (0.80)
#           4          0.20 (0.30)      0.34 (0.25)      -0.04 (0.85)
# regdata31 3         -0.34 (0.39)   -1.01 (0.05)**    -0.87 (0.02)**
#           4         -0.37 (0.22)     -0.49 (0.14)    -0.57 (0.02)**

# %%
from statsmodels.formula import api as smf

safe_data = combined_3digit[['year', 'naics_code', 'estb_birth_rate', 'regdata20']].dropna()
(
    smf.ols('estb_birth_rate ~ np.log(regdata20) + C(year) + C(naics_code)', safe_data)
    .fit()
    .summary()
)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.703
# Method:                 Least Squares   F-statistic:                     26.93
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):          1.35e-174
# Time:                        17:13:16   Log-Likelihood:                -2056.8
# No. Observations:                 868   AIC:                             4274.
# Df Residuals:                     788   BIC:                             4655.
# Df Model:                          79
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                9.8202      3.122      3.146      0.002       3.692      15.948
# C(year)[T.2000]          0.3600      0.475      0.758      0.448      -0.572       1.292
# C(year)[T.2001]          0.4108      0.473      0.868      0.385      -0.518       1.339
# C(year)[T.2002]         -0.3962      0.473     -0.837      0.403      -1.325       0.532
# C(year)[T.2003]          0.4345      0.473      0.918      0.359      -0.495       1.364
# C(year)[T.2004]         -0.5132      0.474     -1.083      0.279      -1.443       0.417
# C(year)[T.2005]          0.2221      0.475      0.467      0.640      -0.711       1.155
# C(year)[T.2006]          1.3652      0.474      2.880      0.004       0.435       2.296
# C(year)[T.2007]         -1.5452      0.475     -3.253      0.001      -2.478      -0.613
# C(year)[T.2008]         -2.5060      0.476     -5.263      0.000      -3.441      -1.571
# C(year)[T.2009]         -2.6114      0.475     -5.493      0.000      -3.545      -1.678
# C(year)[T.2010]         -1.9612      0.478     -4.100      0.000      -2.900      -1.022
# C(year)[T.2011]         -0.2964      0.479     -0.619      0.536      -1.237       0.644
# C(naics_code)[T.114]     6.2962      2.368      2.659      0.008       1.648      10.944
# C(naics_code)[T.211]    -0.3049      2.416     -0.126      0.900      -5.047       4.437
# C(naics_code)[T.212]    -2.6199      2.439     -1.074      0.283      -7.407       2.168
# C(naics_code)[T.221]    -3.1735      1.705     -1.862      0.063      -6.520       0.173
# C(naics_code)[T.236]     5.0526      2.281      2.215      0.027       0.575       9.531
# C(naics_code)[T.237]     0.8639      3.559      0.243      0.808      -6.123       7.851
# C(naics_code)[T.311]    -2.7032      2.386     -1.133      0.258      -7.388       1.981
# C(naics_code)[T.312]     3.5415      1.513      2.341      0.019       0.572       6.511
# C(naics_code)[T.313]    -3.5918      1.065     -3.372      0.001      -5.683      -1.501
# C(naics_code)[T.314]    -1.8771      1.065     -1.762      0.078      -3.968       0.214
# C(naics_code)[T.315]     4.7128      1.396      3.376      0.001       1.972       7.453
# C(naics_code)[T.316]    -0.7542      1.550     -0.487      0.627      -3.797       2.289
# C(naics_code)[T.321]    -2.9868      1.085     -2.752      0.006      -5.117      -0.856
# C(naics_code)[T.322]    -6.5215      1.349     -4.834      0.000      -9.170      -3.873
# C(naics_code)[T.323]    -4.7793      1.122     -4.260      0.000      -6.982      -2.577
# C(naics_code)[T.324]    -3.0562      1.892     -1.615      0.107      -6.771       0.658
# C(naics_code)[T.325]    -4.2280      1.732     -2.441      0.015      -7.628      -0.828
# C(naics_code)[T.326]    -5.8176      1.307     -4.452      0.000      -8.383      -3.253
# C(naics_code)[T.327]    -3.4417      1.273     -2.703      0.007      -5.941      -0.943
# C(naics_code)[T.331]    -2.9649      1.383     -2.144      0.032      -5.680      -0.250
# C(naics_code)[T.332]    -4.4548      1.151     -3.870      0.000      -6.715      -2.195
# C(naics_code)[T.333]    -5.0027      1.218     -4.106      0.000      -7.395      -2.611
# C(naics_code)[T.334]    -3.3084      1.261     -2.625      0.009      -5.783      -0.834
# C(naics_code)[T.335]    -4.3010      1.169     -3.681      0.000      -6.595      -2.007
# C(naics_code)[T.336]    -2.6184      2.110     -1.241      0.215      -6.760       1.523
# C(naics_code)[T.337]    -2.3563      1.304     -1.806      0.071      -4.917       0.204
# C(naics_code)[T.441]    -2.2357      1.379     -1.621      0.105      -4.943       0.471
# C(naics_code)[T.442]    -0.6527      1.141     -0.572      0.568      -2.893       1.587
# C(naics_code)[T.443]     3.4805      2.091      1.665      0.096      -0.624       7.585
# C(naics_code)[T.444]    -3.2925      1.796     -1.833      0.067      -6.819       0.234
# C(naics_code)[T.447]    -2.5058      1.229     -2.038      0.042      -4.919      -0.093
# C(naics_code)[T.448]    -1.0116      1.136     -0.891      0.373      -3.241       1.218
# C(naics_code)[T.451]    -0.5678      1.525     -0.372      0.710      -3.562       2.427
# C(naics_code)[T.481]     0.1313      2.142      0.061      0.951      -4.073       4.335
# C(naics_code)[T.483]     0.7163      2.039      0.351      0.725      -3.286       4.719
# C(naics_code)[T.484]     4.4757      2.210      2.026      0.043       0.138       8.813
# C(naics_code)[T.485]     2.3673      2.261      1.047      0.295      -2.072       6.806
# C(naics_code)[T.486]     3.1796      1.087      2.925      0.004       1.046       5.313
# C(naics_code)[T.487]     4.4893      2.086      2.153      0.032       0.395       8.583
# C(naics_code)[T.493]     0.8586      1.415      0.607      0.544      -1.920       3.637
# C(naics_code)[T.511]     0.0320      1.089      0.029      0.977      -2.106       2.170
# C(naics_code)[T.512]     4.2740      1.170      3.652      0.000       1.977       6.571
# C(naics_code)[T.517]     6.1077      1.451      4.210      0.000       3.260       8.955
# C(naics_code)[T.518]    11.7465      1.443      8.140      0.000       8.914      14.579
# C(naics_code)[T.521]     3.1167      1.118      2.788      0.005       0.923       5.311
# C(naics_code)[T.522]     1.7607      3.156      0.558      0.577      -4.435       7.956
# C(naics_code)[T.523]     6.8353      2.838      2.408      0.016       1.263      12.407
# C(naics_code)[T.524]    -0.2397      2.122     -0.113      0.910      -4.406       3.926
# C(naics_code)[T.525]    13.9463      1.836      7.597      0.000      10.343      17.550
# C(naics_code)[T.531]     3.6211      1.097      3.302      0.001       1.468       5.774
# C(naics_code)[T.532]    -0.2325      1.716     -0.135      0.892      -3.601       3.136
# C(naics_code)[T.533]     3.7966      1.929      1.968      0.049       0.009       7.584
# C(naics_code)[T.541]     3.4239      1.161      2.949      0.003       1.145       5.703
# C(naics_code)[T.561]     3.3496      2.548      1.314      0.189      -1.652       8.352
# C(naics_code)[T.562]     0.7888      2.208      0.357      0.721      -3.545       5.123
# C(naics_code)[T.611]     1.3945      1.541      0.905      0.366      -1.631       4.420
# C(naics_code)[T.621]    -1.3716      1.204     -1.139      0.255      -3.735       0.992
# C(naics_code)[T.622]    -4.7256      1.733     -2.727      0.007      -8.127      -1.324
# C(naics_code)[T.623]    -1.0808      1.224     -0.883      0.378      -3.484       1.323
# C(naics_code)[T.711]     6.8772      1.598      4.303      0.000       3.740      10.014
# C(naics_code)[T.712]    -3.3233      1.285     -2.587      0.010      -5.845      -0.801
# C(naics_code)[T.713]     2.0794      1.091      1.906      0.057      -0.062       4.221
# C(naics_code)[T.721]    -0.0757      1.065     -0.071      0.943      -2.167       2.015
# C(naics_code)[T.722]     2.7564      1.152      2.392      0.017       0.494       5.019
# C(naics_code)[T.812]     2.3962      1.078      2.224      0.026       0.281       4.511
# C(naics_code)[T.813]    -4.8373      1.149     -4.210      0.000      -7.093      -2.582
# np.log(regdata20)        0.1611      0.516      0.312      0.755      -0.852       1.174
# ==============================================================================
# Omnibus:                      417.911   Durbin-Watson:                   1.748
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9825.977
# Skew:                           1.652   Prob(JB):                         0.00
# Kurtosis:                      19.148   Cond. No.                         905.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
