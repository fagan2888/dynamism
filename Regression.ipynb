# %%
import itertools

import pandas as pd
import numpy as np

import linearmodels

from pathlib import Path

# %% [markdown]
# # Prep
# Read in data and create output directory

# %%
combined_3digit = pd.read_csv('data/final/combined_3digit.csv')
combined_3digit.head()
# Out:
#      year  naics_code  empl_births  empl_contract  empl_deaths  empl_expand  \
# 0  1998.0         113       5619.0       -10608.0      -6013.0      10818.0
# 1  1998.0         114       1106.0        -1244.0       -785.0       1579.0
# 2  1998.0         115       8096.0       -11921.0      -6773.0      14643.0
# 3  1998.0         211       5945.0       -15757.0      -5644.0       8268.0
# 4  1998.0         212       7521.0       -22715.0     -10536.0      16639.0
#
#    empl_initial  estb_births  estb_contract  estb_deaths  ...  empl_destroyed  \
# 0       84150.0       1446.0         3495.0       1647.0  ...         16621.0
# 1        9312.0        287.0          267.0        233.0  ...          2029.0
# 2       93588.0       1190.0         2104.0       1095.0  ...         18694.0
# 3       97037.0        564.0         2043.0        968.0  ...         21401.0
# 4      225356.0        598.0         2266.0        636.0  ...         33251.0
#
#    estb_dhs  empl_dhs  estb_birth_rate  empl_create_rate  empl_destroy_rate  \
# 0       NaN       NaN              NaN               NaN                NaN
# 1       NaN       NaN              NaN               NaN                NaN
# 2       NaN       NaN              NaN               NaN                NaN
# 3       NaN       NaN              NaN               NaN                NaN
# 4       NaN       NaN              NaN               NaN                NaN
#
#       regdata20     regdata21     regdata22   regdata31
# 0    393.953985   4387.428106           NaN         NaN
# 1  19014.211936  16010.209662   5592.539131   3316.4159
# 2           NaN           NaN   2145.552466   1553.9040
# 3  22298.961579  66989.810756  10369.798674   4184.1912
# 4  25860.865965  21824.120103           NaN  12604.6857
#
# [5 rows x 23 columns]

# %%
combined_4digit = pd.read_csv('data/final/combined_4digit.csv')
combined_3digit.head()
# Out:
#      year  naics_code  empl_births  empl_contract  empl_deaths  empl_expand  \
# 0  1998.0         113       5619.0       -10608.0      -6013.0      10818.0
# 1  1998.0         114       1106.0        -1244.0       -785.0       1579.0
# 2  1998.0         115       8096.0       -11921.0      -6773.0      14643.0
# 3  1998.0         211       5945.0       -15757.0      -5644.0       8268.0
# 4  1998.0         212       7521.0       -22715.0     -10536.0      16639.0
#
#    empl_initial  estb_births  estb_contract  estb_deaths  ...  empl_destroyed  \
# 0       84150.0       1446.0         3495.0       1647.0  ...         16621.0
# 1        9312.0        287.0          267.0        233.0  ...          2029.0
# 2       93588.0       1190.0         2104.0       1095.0  ...         18694.0
# 3       97037.0        564.0         2043.0        968.0  ...         21401.0
# 4      225356.0        598.0         2266.0        636.0  ...         33251.0
#
#    estb_dhs  empl_dhs  estb_birth_rate  empl_create_rate  empl_destroy_rate  \
# 0       NaN       NaN              NaN               NaN                NaN
# 1       NaN       NaN              NaN               NaN                NaN
# 2       NaN       NaN              NaN               NaN                NaN
# 3       NaN       NaN              NaN               NaN                NaN
# 4       NaN       NaN              NaN               NaN                NaN
#
#       regdata20     regdata21     regdata22   regdata31
# 0    393.953985   4387.428106           NaN         NaN
# 1  19014.211936  16010.209662   5592.539131   3316.4159
# 2           NaN           NaN   2145.552466   1553.9040
# 3  22298.961579  66989.810756  10369.798674   4184.1912
# 4  25860.865965  21824.120103           NaN  12604.6857
#
# [5 rows x 23 columns]

# %%
Path('data/tables').mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Summary Tables

# %%
summary_table_rows = {
    'estb_birth_rate': 'Startup Rate',
    'empl_create_rate': 'Job Creation Rate',
    'empl_destroy_rate': 'Job Destruction Rate',
    'estb_births': 'Establishment Births',
    'estb_deaths': 'Establishment Deaths',
    'empl_created': 'New Hires',
    'regdata20': 'RegData 2.0 Regulation Index',
    'regdata21': 'RegData 2.1 Regulation Index',
    'regdata22': 'RegData 2.2 Regulation Index',
    'regdata31': 'RegData 3.1 Regulation Index'
}

summary_3digit = (
    combined_3digit
    .loc[lambda df: df['year'] <= 2010]
    .describe()
    [[i for i in summary_table_rows if i in combined_3digit]]
    .round(2)
    .rename(columns=summary_table_rows)
    .T
    [['count', 'mean', 'std', 'min', 'max']]
    .rename(columns={'std':'standard deviation'})
    .assign(count=lambda df: df['count'].astype(int))
    .applymap(lambda x: f'{x:,.0f}' if x > 100 else f'{x:.02f}')
)
summary_3digit.to_csv('data/tables/summary_3digit.csv')
summary_3digit.to_latex('data/tables/summary_3digit.tex')
summary_3digit
# Out:
#                               count     mean standard deviation    min  \
# Startup Rate                  1,030    10.84               4.83   1.05
# Job Creation Rate               970    14.58               6.65   1.35
# Job Destruction Rate            969    15.11               5.33   0.94
# Establishment Births          1,118    8,422             14,666   1.00
# Establishment Deaths          1,116    8,110             13,526   1.00
# New Hires                     1,075  209,215            333,911    746
# RegData 2.0 Regulation Index    869    5,480             10,007   0.36
# RegData 2.1 Regulation Index    975   32,585             28,725  4,387
# RegData 2.2 Regulation Index    650    8,717             13,006  21.12
# RegData 3.1 Regulation Index    650   16,644             20,416    233
#
#                                     max
# Startup Rate                      46.15
# Job Creation Rate                 81.29
# Job Destruction Rate              61.84
# Establishment Births            105,010
# Establishment Deaths             94,476
# New Hires                     2,297,342
# RegData 2.0 Regulation Index     63,506
# RegData 2.1 Regulation Index    143,593
# RegData 2.2 Regulation Index     66,351
# RegData 3.1 Regulation Index     97,502

# %%
summary_4digit = (
    combined_4digit.describe()
    [[i for i in summary_table_rows if i in combined_4digit]]
    .round(2)
    .rename(columns=summary_table_rows)
    .T
    [['count', 'mean', 'std', 'min', 'max']]
    .rename(columns={'std':'standard deviation'})
    .assign(count=lambda df: df['count'].astype(int))
    .applymap(lambda x: f'{x:,.0f}' if x > 100 else f'{x:.02f}')
)
summary_4digit.to_csv('data/tables/summary_4digit.csv')
summary_4digit.to_latex('data/tables/summary_4digit.tex')
summary_4digit
# Out:
#                               count    mean standard deviation   min  \
# Startup Rate                  4,056   10.58               8.05  0.00
# Job Creation Rate             3,658   14.57               6.80  1.35
# Job Destruction Rate          3,645   14.78               5.75  0.94
# Establishment Births          4,637   2,482              4,423  1.00
# Establishment Deaths          4,636   2,353              4,090  1.00
# New Hires                     4,377  61,888            115,468   162
# RegData 2.0 Regulation Index  2,956   1,124              3,935  0.00
# RegData 2.2 Regulation Index  1,632   2,778              3,970  8.61
# RegData 3.1 Regulation Index  2,142  10,226             16,530   149
#
#                                     max
# Startup Rate                        370
# Job Creation Rate                 84.67
# Job Destruction Rate              81.63
# Establishment Births             38,742
# Establishment Deaths             40,944
# New Hires                     1,396,593
# RegData 2.0 Regulation Index     36,131
# RegData 2.2 Regulation Index     25,482
# RegData 3.1 Regulation Index     84,274

# %% [markdown]
# # Regressions

# %%
def get_model(dep, ind, data, logdep=True, cluster=False):
    safe_data = (
        data
        [[dep, ind, 'naics_code', 'year']]
        .dropna()
        .set_index(['naics_code', 'year'])
    )
    if logdep:
        formula = f'np.log({dep}) ~ 1 + np.log({ind}) + EntityEffects + TimeEffects'
    else:
        formula = f'{dep} ~ 1 + np.log({ind}) + EntityEffects + TimeEffects'
    print(formula)
    model = linearmodels.PanelOLS.from_formula(formula, data=safe_data)
    if cluster:
        fitted = model.fit(cov_type='clustered', cluster_entity=True)
    else:
        fitted = model.fit(cov_type='robust')
    print(fitted.summary)
    return (
        fitted.params[1],
        fitted.std_errors[1],
        fitted.pvalues[1]
    )

# %%
DIGITS = (
    (3, combined_3digit),
    (4, combined_4digit)
)

INDVARS = (
    'regdata20',
    'regdata21',
    'regdata22',
    'regdata31',
)

DEPVARS = (
    ('estb_births', True), # Variable, Log
    ('estb_deaths', True),
    ('empl_created', True),
    ('estb_birth_rate', False),
    ('empl_create_rate', False),
    ('empl_destroy_rate', False)
)

CLUSTER = (True, False)

# %%
results = []
for (digits, data), indvar, (depvar, logdep), cluster in itertools.product(DIGITS, INDVARS, DEPVARS, CLUSTER):
    if not indvar in data:
        continue
    param, stderr, pval = get_model(depvar, indvar, data, logdep, cluster)
    results.append([digits, depvar, indvar, param, stderr, pval, 'clustered' if cluster else 'robust'])
results = pd.DataFrame(results, columns=['digits', 'depvar', 'indvar', 'param', 'stderr', 'pval', 'errtype'])
# Out:
# np.log(estb_births) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_births)   R-squared:                        0.0025
# Estimator:                    PanelOLS   R-squared (Between):              0.0040
# No. Observations:                  936   R-squared (Within):               0.0065
# Date:                 Thu, Jun 13 2019   R-squared (Overall):              0.0030
# Time:                         16:07:12   Log-likelihood                    47.611
# Cov. Estimator:              Clustered
#                                          F-statistic:                      2.1099
# Entities:                           67   P-value                           0.1467
# Avg Obs:                        13.970   Distribution:                   F(1,855)
# Min Obs:                        12.000
# Max Obs:                        14.000   F-statistic (robust):             0.5199
#                                          P-value                           0.4711
# Time periods:                       14   Distribution:                   F(1,855)
# Avg Obs:                        66.857
# Min Obs:                        66.000
# Max Obs:                        67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.0225     0.5770     13.905     0.0000      6.8901      9.1549
# np.log(regdata20)    -0.0623     0.0863    -0.7211     0.4711     -0.2317      0.1072
# =====================================================================================
#
# F-test for Poolability: 672.65
# P-value: 0.0000
# Distribution: F(79,855)
#
# Included effects: Entity, Time
# np.log(estb_births) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_births)   R-squared:                        0.0025
# Estimator:                    PanelOLS   R-squared (Between):              0.0040
# No. Observations:                  936   R-squared (Within):               0.0065
# Date:                 Thu, Jun 13 2019   R-squared (Overall):              0.0030
# Time:                         16:07:12   Log-likelihood                    47.611
# Cov. Estimator:                 Robust
#                                          F-statistic:                      2.1099
# Entities:                           67   P-value                           0.1467
# Avg Obs:                        13.970   Distribution:                   F(1,855)
# Min Obs:                        12.000
# Max Obs:                        14.000   F-statistic (robust):             1.8912
#                                          P-value                           0.1694
# Time periods:                       14   Distribution:                   F(1,855)
# Avg Obs:                        66.857
# Min Obs:                        66.000
# Max Obs:                        67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.0225     0.3025     26.524     0.0000      7.4288      8.6162
# np.log(regdata20)    -0.0623     0.0453    -1.3752     0.1694     -0.1511      0.0266
# =====================================================================================
#
# F-test for Poolability: 672.65
# P-value: 0.0000
# Distribution: F(79,855)
#
# Included effects: Entity, Time
# np.log(estb_deaths) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_deaths)   R-squared:                        0.0047
# Estimator:                    PanelOLS   R-squared (Between):              0.0071
# No. Observations:                  934   R-squared (Within):               0.0070
# Date:                 Thu, Jun 13 2019   R-squared (Overall):              0.0065
# Time:                         16:07:13   Log-likelihood                    121.99
# Cov. Estimator:              Clustered
#                                          F-statistic:                      4.0096
# Entities:                           67   P-value                           0.0456
# Avg Obs:                        13.940   Distribution:                   F(1,853)
# Min Obs:                        12.000
# Max Obs:                        14.000   F-statistic (robust):             0.5599
#                                          P-value                           0.4545
# Time periods:                       14   Distribution:                   F(1,853)
# Avg Obs:                        66.714
# Min Obs:                        65.000
# Max Obs:                        67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.1543     0.7084     11.511     0.0000      6.7639      9.5447
# np.log(regdata20)    -0.0793     0.1060    -0.7482     0.4545     -0.2873      0.1287
# =====================================================================================
#
# F-test for Poolability: 782.20
# P-value: 0.0000
# Distribution: F(79,853)
#
# Included effects: Entity, Time
# np.log(estb_deaths) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_deaths)   R-squared:                        0.0047
# Estimator:                    PanelOLS   R-squared (Between):              0.0071
# No. Observations:                  934   R-squared (Within):               0.0070
# Date:                 Thu, Jun 13 2019   R-squared (Overall):              0.0065
# Time:                         16:07:13   Log-likelihood                    121.99
# Cov. Estimator:                 Robust
#                                          F-statistic:                      4.0096
# Entities:                           67   P-value                           0.0456
# Avg Obs:                        13.940   Distribution:                   F(1,853)
# Min Obs:                        12.000
# Max Obs:                        14.000   F-statistic (robust):             2.9201
#                                          P-value                           0.0878
# Time periods:                       14   Distribution:                   F(1,853)
# Avg Obs:                        66.714
# Min Obs:                        65.000
# Max Obs:                        67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.1543     0.3105     26.258     0.0000      7.5448      8.7638
# np.log(regdata20)    -0.0793     0.0464    -1.7088     0.0878     -0.1704      0.0118
# =====================================================================================
#
# F-test for Poolability: 782.20
# P-value: 0.0000
# Distribution: F(79,853)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0292
# Estimator:                     PanelOLS   R-squared (Between):             -0.0730
# No. Observations:                   894   R-squared (Within):               0.0497
# Date:                  Thu, Jun 13 2019   R-squared (Overall):             -0.0999
# Time:                          16:07:13   Log-likelihood                    96.991
# Cov. Estimator:               Clustered
#                                           F-statistic:                      24.463
# Entities:                            67   P-value                           0.0000
# Avg Obs:                         13.343   Distribution:                   F(1,813)
# Min Obs:                         2.0000
# Max Obs:                         14.000   F-statistic (robust):             2.5796
#                                           P-value                           0.1086
# Time periods:                        14   Distribution:                   F(1,813)
# Avg Obs:                         63.857
# Min Obs:                         61.000
# Max Obs:                         67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             12.628     0.8512     14.836     0.0000      10.957      14.298
# np.log(regdata20)    -0.2059     0.1282    -1.6061     0.1086     -0.4576      0.0457
# =====================================================================================
#
# F-test for Poolability: 471.70
# P-value: 0.0000
# Distribution: F(79,813)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0292
# Estimator:                     PanelOLS   R-squared (Between):             -0.0730
# No. Observations:                   894   R-squared (Within):               0.0497
# Date:                  Thu, Jun 13 2019   R-squared (Overall):             -0.0999
# Time:                          16:07:13   Log-likelihood                    96.991
# Cov. Estimator:                  Robust
#                                           F-statistic:                      24.463
# Entities:                            67   P-value                           0.0000
# Avg Obs:                         13.343   Distribution:                   F(1,813)
# Min Obs:                         2.0000
# Max Obs:                         14.000   F-statistic (robust):             17.182
#                                           P-value                           0.0000
# Time periods:                        14   Distribution:                   F(1,813)
# Avg Obs:                         63.857
# Min Obs:                         61.000
# Max Obs:                         67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             12.628     0.3300     38.266     0.0000      11.980      13.275
# np.log(regdata20)    -0.2059     0.0497    -4.1452     0.0000     -0.3035     -0.1084
# =====================================================================================
#
# F-test for Poolability: 471.70
# P-value: 0.0000
# Distribution: F(79,813)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0001
# Estimator:                   PanelOLS   R-squared (Between):              0.0158
# No. Observations:                 868   R-squared (Within):              -0.0012
# Date:                Thu, Jun 13 2019   R-squared (Overall):              0.0104
# Time:                        16:07:13   Log-likelihood                   -2056.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.0974
# Entities:                          67   P-value                           0.7550
# Avg Obs:                       12.955   Distribution:                   F(1,788)
# Min Obs:                       11.000
# Max Obs:                       13.000   F-statistic (robust):             0.0437
#                                         P-value                           0.8346
# Time periods:                      13   Distribution:                   F(1,788)
# Avg Obs:                       66.769
# Min Obs:                       65.000
# Max Obs:                       67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             9.5887     5.1527     1.8609     0.0631     -0.5260      19.703
# np.log(regdata20)     0.1611     0.7709     0.2089     0.8346     -1.3522      1.6744
# =====================================================================================
#
# F-test for Poolability: 26.859
# P-value: 0.0000
# Distribution: F(78,788)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0001
# Estimator:                   PanelOLS   R-squared (Between):              0.0158
# No. Observations:                 868   R-squared (Within):              -0.0012
# Date:                Thu, Jun 13 2019   R-squared (Overall):              0.0104
# Time:                        16:07:13   Log-likelihood                   -2056.8
# Cov. Estimator:                Robust
#                                         F-statistic:                      0.0974
# Entities:                          67   P-value                           0.7550
# Avg Obs:                       12.955   Distribution:                   F(1,788)
# Min Obs:                       11.000
# Max Obs:                       13.000   F-statistic (robust):             0.1256
#                                         P-value                           0.7232
# Time periods:                      13   Distribution:                   F(1,788)
# Avg Obs:                       66.769
# Min Obs:                       65.000
# Max Obs:                       67.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             9.5887     3.0414     3.1527     0.0017      3.6184      15.559
# np.log(regdata20)     0.1611     0.4546     0.3544     0.7232     -0.7312      1.0534
# =====================================================================================
#
# F-test for Poolability: 26.859
# P-value: 0.0000
# Distribution: F(78,788)
#
# Included effects: Entity, Time
# empl_create_rate ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0022
# Estimator:                   PanelOLS   R-squared (Between):             -0.2217
# No. Observations:                 811   R-squared (Within):               0.0083
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.1251
# Time:                        16:07:14   Log-likelihood                   -2210.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.6201
# Entities:                          66   P-value                           0.2035
# Avg Obs:                       12.288   Distribution:                   F(1,732)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             0.9371
#                                         P-value                           0.3333
# Time periods:                      13   Distribution:                   F(1,732)
# Avg Obs:                       62.385
# Min Obs:                       61.000
# Max Obs:                       65.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             20.428     6.5828     3.1032     0.0020      7.5046      33.352
# np.log(regdata20)    -0.9652     0.9971    -0.9680     0.3333     -2.9226      0.9922
# =====================================================================================
#
# F-test for Poolability: 20.181
# P-value: 0.0000
# Distribution: F(77,732)
#
# Included effects: Entity, Time
# empl_create_rate ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0022
# Estimator:                   PanelOLS   R-squared (Between):             -0.2217
# No. Observations:                 811   R-squared (Within):               0.0083
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.1251
# Time:                        16:07:14   Log-likelihood                   -2210.1
# Cov. Estimator:                Robust
#                                         F-statistic:                      1.6201
# Entities:                          66   P-value                           0.2035
# Avg Obs:                       12.288   Distribution:                   F(1,732)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             2.9548
#                                         P-value                           0.0860
# Time periods:                      13   Distribution:                   F(1,732)
# Avg Obs:                       62.385
# Min Obs:                       61.000
# Max Obs:                       65.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             20.428     3.7397     5.4625     0.0000      13.086      27.770
# np.log(regdata20)    -0.9652     0.5615    -1.7189     0.0860     -2.0675      0.1372
# =====================================================================================
#
# F-test for Poolability: 20.181
# P-value: 0.0000
# Distribution: F(77,732)
#
# Included effects: Entity, Time
# empl_destroy_rate ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:      empl_destroy_rate   R-squared:                        0.0007
# Estimator:                   PanelOLS   R-squared (Between):             -0.0462
# No. Observations:                 808   R-squared (Within):               0.0042
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.0149
# Time:                        16:07:14   Log-likelihood                   -2021.3
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.5196
# Entities:                          66   P-value                           0.4713
# Avg Obs:                       12.242   Distribution:                   F(1,729)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             0.4299
#                                         P-value                           0.5122
# Time periods:                      13   Distribution:                   F(1,729)
# Avg Obs:                       62.154
# Min Obs:                       60.000
# Max Obs:                       66.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             17.600     4.4140     3.9872     0.0001      8.9340      26.266
# np.log(regdata20)    -0.4386     0.6689    -0.6557     0.5122     -1.7518      0.8746
# =====================================================================================
#
# F-test for Poolability: 21.879
# P-value: 0.0000
# Distribution: F(77,729)
#
# Included effects: Entity, Time
# empl_destroy_rate ~ 1 + np.log(regdata20) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:      empl_destroy_rate   R-squared:                        0.0007
# Estimator:                   PanelOLS   R-squared (Between):             -0.0462
# No. Observations:                 808   R-squared (Within):               0.0042
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.0149
# Time:                        16:07:14   Log-likelihood                   -2021.3
# Cov. Estimator:                Robust
#                                         F-statistic:                      0.5196
# Entities:                          66   P-value                           0.4713
# Avg Obs:                       12.242   Distribution:                   F(1,729)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             1.3196
#                                         P-value                           0.2510
# Time periods:                      13   Distribution:                   F(1,729)
# Avg Obs:                       62.154
# Min Obs:                       60.000
# Max Obs:                       66.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             17.600     2.5306     6.9548     0.0000      12.632      22.568
# np.log(regdata20)    -0.4386     0.3818    -1.1487     0.2510     -1.1881      0.3110
# =====================================================================================
#
# F-test for Poolability: 21.879
# P-value: 0.0000
# Distribution: F(77,729)
#
# Included effects: Entity, Time
# np.log(estb_births) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_births)   R-squared:                        0.0188
# Estimator:                    PanelOLS   R-squared (Between):             -0.0923
# No. Observations:                 1125   R-squared (Within):               0.0681
# Date:                 Thu, Jun 13 2019   R-squared (Overall):             -0.0886
# Time:                         16:07:14   Log-likelihood                    118.80
# Cov. Estimator:              Clustered
#                                          F-statistic:                      19.789
# Entities:                           75   P-value                           0.0000
# Avg Obs:                        15.000   Distribution:                  F(1,1035)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             5.1235
#                                          P-value                           0.0238
# Time periods:                       15   Distribution:                  F(1,1035)
# Avg Obs:                        75.000
# Min Obs:                        75.000
# Max Obs:                        75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             11.068     1.4118     7.8392     0.0000      8.2972      13.838
# np.log(regdata21)    -0.3168     0.1400    -2.2635     0.0238     -0.5914     -0.0422
# =====================================================================================
#
# F-test for Poolability: 597.31
# P-value: 0.0000
# Distribution: F(88,1035)
#
# Included effects: Entity, Time
# np.log(estb_births) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_births)   R-squared:                        0.0188
# Estimator:                    PanelOLS   R-squared (Between):             -0.0923
# No. Observations:                 1125   R-squared (Within):               0.0681
# Date:                 Thu, Jun 13 2019   R-squared (Overall):             -0.0886
# Time:                         16:07:15   Log-likelihood                    118.80
# Cov. Estimator:                 Robust
#                                          F-statistic:                      19.789
# Entities:                           75   P-value                           0.0000
# Avg Obs:                        15.000   Distribution:                  F(1,1035)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             14.915
#                                          P-value                           0.0001
# Time periods:                       15   Distribution:                  F(1,1035)
# Avg Obs:                        75.000
# Min Obs:                        75.000
# Max Obs:                        75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             11.068     0.8273     13.377     0.0000      9.4441      12.691
# np.log(regdata21)    -0.3168     0.0820    -3.8621     0.0001     -0.4778     -0.1558
# =====================================================================================
#
# F-test for Poolability: 597.31
# P-value: 0.0000
# Distribution: F(88,1035)
#
# Included effects: Entity, Time
# np.log(estb_deaths) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_deaths)   R-squared:                        0.0110
# Estimator:                    PanelOLS   R-squared (Between):             -0.0641
# No. Observations:                 1125   R-squared (Within):               0.0391
# Date:                 Thu, Jun 13 2019   R-squared (Overall):             -0.0618
# Time:                         16:07:15   Log-likelihood                    98.153
# Cov. Estimator:              Clustered
#                                          F-statistic:                      11.476
# Entities:                           75   P-value                           0.0007
# Avg Obs:                        15.000   Distribution:                  F(1,1035)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             2.0745
#                                          P-value                           0.1501
# Time periods:                       15   Distribution:                  F(1,1035)
# Avg Obs:                        75.000
# Min Obs:                        75.000
# Max Obs:                        75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             10.347     1.7209     6.0125     0.0000      6.9700      13.724
# np.log(regdata21)    -0.2457     0.1706    -1.4403     0.1501     -0.5805      0.0890
# =====================================================================================
#
# F-test for Poolability: 564.66
# P-value: 0.0000
# Distribution: F(88,1035)
#
# Included effects: Entity, Time
# np.log(estb_deaths) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     np.log(estb_deaths)   R-squared:                        0.0110
# Estimator:                    PanelOLS   R-squared (Between):             -0.0641
# No. Observations:                 1125   R-squared (Within):               0.0391
# Date:                 Thu, Jun 13 2019   R-squared (Overall):             -0.0618
# Time:                         16:07:15   Log-likelihood                    98.153
# Cov. Estimator:                 Robust
#                                          F-statistic:                      11.476
# Entities:                           75   P-value                           0.0007
# Avg Obs:                        15.000   Distribution:                  F(1,1035)
# Min Obs:                        15.000
# Max Obs:                        15.000   F-statistic (robust):             6.3132
#                                          P-value                           0.0121
# Time periods:                       15   Distribution:                  F(1,1035)
# Avg Obs:                        75.000
# Min Obs:                        75.000
# Max Obs:                        75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             10.347     0.9863     10.491     0.0000      8.4115      12.282
# np.log(regdata21)    -0.2457     0.0978    -2.5126     0.0121     -0.4376     -0.0538
# =====================================================================================
#
# F-test for Poolability: 564.66
# P-value: 0.0000
# Distribution: F(88,1035)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0392
# Estimator:                     PanelOLS   R-squared (Between):             -0.2233
# No. Observations:                  1093   R-squared (Within):               0.1291
# Date:                  Thu, Jun 13 2019   R-squared (Overall):             -0.2258
# Time:                          16:07:15   Log-likelihood                   -14.461
# Cov. Estimator:               Clustered
#                                           F-statistic:                      40.971
# Entities:                            75   P-value                           0.0000
# Avg Obs:                         14.573   Distribution:                  F(1,1003)
# Min Obs:                         5.0000
# Max Obs:                         15.000   F-statistic (robust):             8.9371
#                                           P-value                           0.0029
# Time periods:                        15   Distribution:                  F(1,1003)
# Avg Obs:                         72.867
# Min Obs:                         70.000
# Max Obs:                         75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             16.665     1.7552     9.4947     0.0000      13.221      20.109
# np.log(regdata21)    -0.5199     0.1739    -2.9895     0.0029     -0.8612     -0.1786
# =====================================================================================
#
# F-test for Poolability: 320.51
# P-value: 0.0000
# Distribution: F(88,1003)
#
# Included effects: Entity, Time
# np.log(empl_created) ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     np.log(empl_created)   R-squared:                        0.0392
# Estimator:                     PanelOLS   R-squared (Between):             -0.2233
# No. Observations:                  1093   R-squared (Within):               0.1291
# Date:                  Thu, Jun 13 2019   R-squared (Overall):             -0.2258
# Time:                          16:07:15   Log-likelihood                   -14.461
# Cov. Estimator:                  Robust
#                                           F-statistic:                      40.971
# Entities:                            75   P-value                           0.0000
# Avg Obs:                         14.573   Distribution:                  F(1,1003)
# Min Obs:                         5.0000
# Max Obs:                         15.000   F-statistic (robust):             25.106
#                                           P-value                           0.0000
# Time periods:                        15   Distribution:                  F(1,1003)
# Avg Obs:                         72.867
# Min Obs:                         70.000
# Max Obs:                         75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             16.665     1.0474     15.910     0.0000      14.610      18.720
# np.log(regdata21)    -0.5199     0.1038    -5.0106     0.0000     -0.7235     -0.3163
# =====================================================================================
#
# F-test for Poolability: 320.51
# P-value: 0.0000
# Distribution: F(88,1003)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0184
# Estimator:                   PanelOLS   R-squared (Between):             -0.6540
# No. Observations:                 975   R-squared (Within):              -0.0716
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.4565
# Time:                        16:07:16   Log-likelihood                   -2263.8
# Cov. Estimator:             Clustered
#                                         F-statistic:                      16.599
# Entities:                          75   P-value                           0.0001
# Avg Obs:                       13.000   Distribution:                   F(1,887)
# Min Obs:                       13.000
# Max Obs:                       13.000   F-statistic (robust):             1.4427
#                                         P-value                           0.2300
# Time periods:                      13   Distribution:                   F(1,887)
# Avg Obs:                       75.000
# Min Obs:                       75.000
# Max Obs:                       75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept            -28.126     32.339    -0.8697     0.3847     -91.596      35.344
# np.log(regdata21)     3.8517     3.2067     1.2011     0.2300     -2.4419      10.145
# =====================================================================================
#
# F-test for Poolability: 27.472
# P-value: 0.0000
# Distribution: F(86,887)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0184
# Estimator:                   PanelOLS   R-squared (Between):             -0.6540
# No. Observations:                 975   R-squared (Within):              -0.0716
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.4565
# Time:                        16:07:16   Log-likelihood                   -2263.8
# Cov. Estimator:                Robust
#                                         F-statistic:                      16.599
# Entities:                          75   P-value                           0.0001
# Avg Obs:                       13.000   Distribution:                   F(1,887)
# Min Obs:                       13.000
# Max Obs:                       13.000   F-statistic (robust):             5.7622
#                                         P-value                           0.0166
# Time periods:                      13   Distribution:                   F(1,887)
# Avg Obs:                       75.000
# Min Obs:                       75.000
# Max Obs:                       75.000
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept            -28.126     16.165    -1.7400     0.0822     -59.852      3.5994
# np.log(regdata21)     3.8517     1.6045     2.4005     0.0166      0.7025      7.0008
# =====================================================================================
#
# F-test for Poolability: 27.472
# P-value: 0.0000
# Distribution: F(86,887)
#
# Included effects: Entity, Time
# empl_create_rate ~ 1 + np.log(regdata21) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0177
# Estimator:                   PanelOLS   R-squared (Between):             -0.8989
# No. Observations:                 929   R-squared (Within):              -0.0713
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.5220
# Time:                        16:07:16   Log-likelihood                   -2553.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      15.176
# Entities:                          75   P-value                           0.0001
# Avg Obs:                       12.387   Distribution:                   F(1,841)
# Min Obs:                       1.0000
# Max Obs:                       13.000   F-statistic (robust):             6.3161
#                                         P-value                           0.0122
# Time periods:                      13   Distribution:                   F(1,841)
# ...
# Estimator:                     PanelOLS   R-squared (Between):             -0.0345
# No. Observations:                  1761   R-squared (Within):              -0.0205
# Date:                  Thu, Jun 13 2019   R-squared (Overall):             -0.0323
# Time:                          16:07:27   Log-likelihood                   -659.56
# Cov. Estimator:                  Robust
#                                           F-statistic:                      6.4807
# Entities:                           119   P-value                           0.0110
# Avg Obs:                         14.798   Distribution:                  F(1,1626)
# Min Obs:                         1.0000
# Max Obs:                         16.000   F-statistic (robust):             5.7605
#                                           P-value                           0.0165
# Time periods:                        16   Distribution:                  F(1,1626)
# Avg Obs:                         110.06
# Min Obs:                         102.00
# Max Obs:                         117.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             8.9129     0.4636     19.223     0.0000      8.0035      9.8223
# np.log(regdata31)     0.1360     0.0567     2.4001     0.0165      0.0249      0.2471
# =====================================================================================
#
# F-test for Poolability: 189.26
# P-value: 0.0000
# Distribution: F(133,1626)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata31) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0007
# Estimator:                   PanelOLS   R-squared (Between):             -0.2613
# No. Observations:                1662   R-squared (Within):              -0.0066
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.0750
# Time:                        16:07:27   Log-likelihood                   -6077.1
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.1472
# Entities:                         119   P-value                           0.2843
# Avg Obs:                       13.966   Distribution:                  F(1,1529)
# Min Obs:                       12.000
# Max Obs:                       14.000   F-statistic (robust):             1.4369
#                                         P-value                           0.2308
# Time periods:                      14   Distribution:                  F(1,1529)
# Avg Obs:                       118.71
# Min Obs:                       117.00
# Max Obs:                       119.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept            -3.6977     11.774    -0.3141     0.7535     -26.792      19.397
# np.log(regdata31)     1.7278     1.4414     1.1987     0.2308     -1.0995      4.5551
# =====================================================================================
#
# F-test for Poolability: 4.5246
# P-value: 0.0000
# Distribution: F(131,1529)
#
# Included effects: Entity, Time
# estb_birth_rate ~ 1 + np.log(regdata31) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:        estb_birth_rate   R-squared:                        0.0007
# Estimator:                   PanelOLS   R-squared (Between):             -0.2613
# No. Observations:                1662   R-squared (Within):              -0.0066
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.0750
# Time:                        16:07:27   Log-likelihood                   -6077.1
# Cov. Estimator:                Robust
#                                         F-statistic:                      1.1472
# Entities:                         119   P-value                           0.2843
# Avg Obs:                       13.966   Distribution:                  F(1,1529)
# Min Obs:                       12.000
# Max Obs:                       14.000   F-statistic (robust):             2.6437
#                                         P-value                           0.1042
# Time periods:                      14   Distribution:                  F(1,1529)
# Avg Obs:                       118.71
# Min Obs:                       117.00
# Max Obs:                       119.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept            -3.6977     8.5372    -0.4331     0.6650     -20.444      13.048
# np.log(regdata31)     1.7278     1.0627     1.6259     0.1042     -0.3566      3.8122
# =====================================================================================
#
# F-test for Poolability: 4.5246
# P-value: 0.0000
# Distribution: F(131,1529)
#
# Included effects: Entity, Time
# empl_create_rate ~ 1 + np.log(regdata31) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0006
# Estimator:                   PanelOLS   R-squared (Between):             -0.1009
# No. Observations:                1469   R-squared (Within):              -0.0103
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.0564
# Time:                        16:07:28   Log-likelihood                   -4367.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.8250
# Entities:                         116   P-value                           0.3639
# Avg Obs:                       12.664   Distribution:                  F(1,1339)
# Min Obs:                       1.0000
# Max Obs:                       14.000   F-statistic (robust):             0.7549
#                                         P-value                           0.3851
# Time periods:                      14   Distribution:                  F(1,1339)
# Avg Obs:                       104.93
# Min Obs:                       94.000
# Max Obs:                       112.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             7.5296     7.2746     1.0351     0.3008     -6.7412      21.800
# np.log(regdata31)     0.7756     0.8927     0.8688     0.3851     -0.9757      2.5269
# =====================================================================================
#
# F-test for Poolability: 14.121
# P-value: 0.0000
# Distribution: F(128,1339)
#
# Included effects: Entity, Time
# empl_create_rate ~ 1 + np.log(regdata31) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:       empl_create_rate   R-squared:                        0.0006
# Estimator:                   PanelOLS   R-squared (Between):             -0.1009
# No. Observations:                1469   R-squared (Within):              -0.0103
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.0564
# Time:                        16:07:28   Log-likelihood                   -4367.2
# Cov. Estimator:                Robust
#                                         F-statistic:                      0.8250
# Entities:                         116   P-value                           0.3639
# Avg Obs:                       12.664   Distribution:                  F(1,1339)
# Min Obs:                       1.0000
# Max Obs:                       14.000   F-statistic (robust):             1.0032
#                                         P-value                           0.3167
# Time periods:                      14   Distribution:                  F(1,1339)
# Avg Obs:                       104.93
# Min Obs:                       94.000
# Max Obs:                       112.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             7.5296     6.2930     1.1965     0.2317     -4.8156      19.875
# np.log(regdata31)     0.7756     0.7744     1.0016     0.3167     -0.7435      2.2948
# =====================================================================================
#
# F-test for Poolability: 14.121
# P-value: 0.0000
# Distribution: F(128,1339)
#
# Included effects: Entity, Time
# empl_destroy_rate ~ 1 + np.log(regdata31) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:      empl_destroy_rate   R-squared:                     2.222e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0185
# No. Observations:                1462   R-squared (Within):              -0.0024
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.0091
# Time:                        16:07:28   Log-likelihood                   -4231.5
# Cov. Estimator:             Clustered
#                                         F-statistic:                      0.0296
# Entities:                         116   P-value                           0.8634
# Avg Obs:                       12.603   Distribution:                  F(1,1332)
# Min Obs:                       1.0000
# Max Obs:                       14.000   F-statistic (robust):             0.0433
#                                         P-value                           0.8352
# Time periods:                      14   Distribution:                  F(1,1332)
# Avg Obs:                       104.43
# Min Obs:                       94.000
# Max Obs:                       112.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             13.160     5.4320     2.4227     0.0155      2.5042      23.817
# np.log(regdata31)     0.1387     0.6667     0.2081     0.8352     -1.1692      1.4466
# =====================================================================================
#
# F-test for Poolability: 12.293
# P-value: 0.0000
# Distribution: F(128,1332)
#
# Included effects: Entity, Time
# empl_destroy_rate ~ 1 + np.log(regdata31) + EntityEffects + TimeEffects
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:      empl_destroy_rate   R-squared:                     2.222e-05
# Estimator:                   PanelOLS   R-squared (Between):             -0.0185
# No. Observations:                1462   R-squared (Within):              -0.0024
# Date:                Thu, Jun 13 2019   R-squared (Overall):             -0.0091
# Time:                        16:07:28   Log-likelihood                   -4231.5
# Cov. Estimator:                Robust
#                                         F-statistic:                      0.0296
# Entities:                         116   P-value                           0.8634
# Avg Obs:                       12.603   Distribution:                  F(1,1332)
# Min Obs:                       1.0000
# Max Obs:                       14.000   F-statistic (robust):             0.0559
#                                         P-value                           0.8131
# Time periods:                      14   Distribution:                  F(1,1332)
# Avg Obs:                       104.43
# Min Obs:                       94.000
# Max Obs:                       112.00
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             13.160     4.7781     2.7543     0.0060      3.7870      22.534
# np.log(regdata31)     0.1387     0.5867     0.2364     0.8131     -1.0123      1.2897
# =====================================================================================
#
# F-test for Poolability: 12.293
# P-value: 0.0000
# Distribution: F(128,1332)
#
# Included effects: Entity, Time

# %% [markdown]
# # Regression Summary Table

# %%
regdata_labels = {
    'regdata20': '2.0',
    'regdata21': '2.1',
    'regdata22': '2.2',
    'regdata31': '3.1',
}

var_labels = {
    'estb_births': 'Log Establishment Births',
    'estb_deaths': 'Log Establishment Deaths',
    'empl_created': 'Log New Hires',
    'estb_birth_rate': 'Startup Rate',
    'empl_create_rate': 'Job Creation Rate',
    'empl_destroy_rate': 'Job Destruction Rate',
}

study_labels = {
    'estb_births': 'Bailey and Thomas Measures',
    'estb_deaths': 'Bailey and Thomas Measures',
    'empl_created': 'Bailey and Thomas Measures',
    'estb_birth_rate': 'Goldschlag and Tabarrok Measures',
    'empl_create_rate': 'Goldschlag and Tabarrok Measures',
    'empl_destroy_rate': 'Goldschlag and Tabarrok Measures',
}

index_labels = {
    'indvar': "RegData Version",
    'digits': "NAICS Level"
}

def format_row(row):
    return (
        f'{row["param"]:01.02f} '
        f'({row["pval"]:01.02f})'
        f'{"*" if row["pval"] < 0.1 else ""}'
        f'{"*" if row["pval"] < 0.05 else ""}'
        f'{"*" if row["pval"] < 0.01 else ""}'
    )

regression_results = (
    results
    .assign(indvar=lambda df: df['indvar'].map(regdata_labels))
    .assign(digits=lambda df: df['digits'].map('{}-digit'.format))
    .assign(study=lambda df: df['depvar'].map(study_labels))
    .rename(columns=index_labels)
    .set_index(['errtype', 'RegData Version', 'NAICS Level', 'study', 'depvar'])
    .apply(format_row, axis=1)
    .unstack(level=['study', 'depvar'])
    .sort_index()
    .rename(columns=var_labels, level=1)
)
regression_results
# Out:
# study                                 Bailey and Thomas Measures  \
# depvar                                  Log Establishment Births
# errtype   RegData Version NAICS Level
# clustered 2.0             3-digit                   -0.06 (0.47)
#                           4-digit                   -0.02 (0.20)
#           2.1             3-digit                 -0.32 (0.02)**
#           2.2             3-digit                    0.05 (0.53)
#                           4-digit                  -0.16 (0.06)*
#           3.1             3-digit                   -0.19 (0.31)
#                           4-digit                    0.18 (0.15)
# robust    2.0             3-digit                   -0.06 (0.17)
#                           4-digit                 -0.02 (0.03)**
#           2.1             3-digit                -0.32 (0.00)***
#           2.2             3-digit                    0.05 (0.18)
#                           4-digit                -0.16 (0.00)***
#           3.1             3-digit                 -0.19 (0.01)**
#                           4-digit                 0.18 (0.00)***
#
# study                                                           \
# depvar                                Log Establishment Deaths
# errtype   RegData Version NAICS Level
# clustered 2.0             3-digit                 -0.08 (0.45)
#                           4-digit                 -0.01 (0.68)
#           2.1             3-digit                 -0.25 (0.15)
#           2.2             3-digit                  0.07 (0.31)
#                           4-digit                 -0.10 (0.17)
#           3.1             3-digit                 -0.22 (0.25)
#                           4-digit                  0.11 (0.33)
# robust    2.0             3-digit                -0.08 (0.09)*
#                           4-digit                 -0.01 (0.49)
#           2.1             3-digit               -0.25 (0.01)**
#           2.2             3-digit                0.07 (0.03)**
#                           4-digit              -0.10 (0.00)***
#           3.1             3-digit              -0.22 (0.00)***
#                           4-digit                0.11 (0.02)**
#
# study                                                   \
# depvar                                   Log New Hires
# errtype   RegData Version NAICS Level
# clustered 2.0             3-digit         -0.21 (0.11)
#                           4-digit      -0.06 (0.01)***
#           2.1             3-digit      -0.52 (0.00)***
#           2.2             3-digit          0.01 (0.90)
#                           4-digit       -0.11 (0.03)**
#           3.1             3-digit         -0.27 (0.13)
#                           4-digit          0.14 (0.32)
# robust    2.0             3-digit      -0.21 (0.00)***
#                           4-digit      -0.06 (0.00)***
#           2.1             3-digit      -0.52 (0.00)***
#           2.2             3-digit          0.01 (0.79)
#                           4-digit      -0.11 (0.00)***
#           3.1             3-digit      -0.27 (0.00)***
#                           4-digit        0.14 (0.02)**
#
# study                                 Goldschlag and Tabarrok Measures  \
# depvar                                                    Startup Rate
# errtype   RegData Version NAICS Level
# clustered 2.0             3-digit                          0.16 (0.83)
#                           4-digit                         -0.02 (0.89)
#           2.1             3-digit                          3.85 (0.23)
#           2.2             3-digit                          0.20 (0.69)
#                           4-digit                         -0.20 (0.63)
#           3.1             3-digit                          0.41 (0.59)
#                           4-digit                          1.73 (0.23)
# robust    2.0             3-digit                          0.16 (0.72)
#                           4-digit                         -0.02 (0.88)
#           2.1             3-digit                        3.85 (0.02)**
#           2.2             3-digit                          0.20 (0.56)
#                           4-digit                         -0.20 (0.51)
#           3.1             3-digit                          0.41 (0.53)
#                           4-digit                          1.73 (0.10)
#
# study
# depvar                                Job Creation Rate Job Destruction Rate
# errtype   RegData Version NAICS Level
# clustered 2.0             3-digit          -0.97 (0.33)         -0.44 (0.51)
#                           4-digit           0.19 (0.36)          0.17 (0.39)
#           2.1             3-digit         5.76 (0.01)**         2.54 (0.06)*
#           2.2             3-digit           0.14 (0.81)          0.41 (0.23)
#                           4-digit          -0.03 (0.95)          0.28 (0.46)
#           3.1             3-digit           1.14 (0.28)          0.42 (0.53)
#                           4-digit           0.78 (0.39)          0.14 (0.84)
# robust    2.0             3-digit         -0.97 (0.09)*         -0.44 (0.25)
#                           4-digit           0.19 (0.27)          0.17 (0.35)
#           2.1             3-digit        5.76 (0.00)***          2.54 (0.13)
#           2.2             3-digit           0.14 (0.76)          0.41 (0.29)
#                           4-digit          -0.03 (0.93)          0.28 (0.37)
#           3.1             3-digit           1.14 (0.21)          0.42 (0.48)
#                           4-digit           0.78 (0.32)          0.14 (0.81)

# %% [markdown]
# ## Results with Robust SEs

# %%
results_robust = regression_results.xs('robust')
results_robust.to_csv('data/tables/regression_summary_robust.csv')
results_robust.to_latex('data/tables/regression_summary_robust.tex')
results_robust
# Out:
# study                       Bailey and Thomas Measures  \
# depvar                        Log Establishment Births
# RegData Version NAICS Level
# 2.0             3-digit                   -0.06 (0.17)
#                 4-digit                 -0.02 (0.03)**
# 2.1             3-digit                -0.32 (0.00)***
# 2.2             3-digit                    0.05 (0.18)
#                 4-digit                -0.16 (0.00)***
# 3.1             3-digit                 -0.19 (0.01)**
#                 4-digit                 0.18 (0.00)***
#
# study                                                                  \
# depvar                      Log Establishment Deaths    Log New Hires
# RegData Version NAICS Level
# 2.0             3-digit                -0.08 (0.09)*  -0.21 (0.00)***
#                 4-digit                 -0.01 (0.49)  -0.06 (0.00)***
# 2.1             3-digit               -0.25 (0.01)**  -0.52 (0.00)***
# 2.2             3-digit                0.07 (0.03)**      0.01 (0.79)
#                 4-digit              -0.10 (0.00)***  -0.11 (0.00)***
# 3.1             3-digit              -0.22 (0.00)***  -0.27 (0.00)***
#                 4-digit                0.11 (0.02)**    0.14 (0.02)**
#
# study                       Goldschlag and Tabarrok Measures  \
# depvar                                          Startup Rate
# RegData Version NAICS Level
# 2.0             3-digit                          0.16 (0.72)
#                 4-digit                         -0.02 (0.88)
# 2.1             3-digit                        3.85 (0.02)**
# 2.2             3-digit                          0.20 (0.56)
#                 4-digit                         -0.20 (0.51)
# 3.1             3-digit                          0.41 (0.53)
#                 4-digit                          1.73 (0.10)
#
# study
# depvar                      Job Creation Rate Job Destruction Rate
# RegData Version NAICS Level
# 2.0             3-digit         -0.97 (0.09)*         -0.44 (0.25)
#                 4-digit           0.19 (0.27)          0.17 (0.35)
# 2.1             3-digit        5.76 (0.00)***          2.54 (0.13)
# 2.2             3-digit           0.14 (0.76)          0.41 (0.29)
#                 4-digit          -0.03 (0.93)          0.28 (0.37)
# 3.1             3-digit           1.14 (0.21)          0.42 (0.48)
#                 4-digit           0.78 (0.32)          0.14 (0.81)

# %% [markdown]
# ## Results with Clustered SEs

# %%
results_robust = regression_results.xs('clustered')
results_robust.to_csv('data/tables/regression_summary_clustered.csv')
results_robust.to_latex('data/tables/regression_summary_clustered.tex')
results_robust
# Out:
# study                       Bailey and Thomas Measures  \
# depvar                        Log Establishment Births
# RegData Version NAICS Level
# 2.0             3-digit                   -0.06 (0.47)
#                 4-digit                   -0.02 (0.20)
# 2.1             3-digit                 -0.32 (0.02)**
# 2.2             3-digit                    0.05 (0.53)
#                 4-digit                  -0.16 (0.06)*
# 3.1             3-digit                   -0.19 (0.31)
#                 4-digit                    0.18 (0.15)
#
# study                                                                  \
# depvar                      Log Establishment Deaths    Log New Hires
# RegData Version NAICS Level
# 2.0             3-digit                 -0.08 (0.45)     -0.21 (0.11)
#                 4-digit                 -0.01 (0.68)  -0.06 (0.01)***
# 2.1             3-digit                 -0.25 (0.15)  -0.52 (0.00)***
# 2.2             3-digit                  0.07 (0.31)      0.01 (0.90)
#                 4-digit                 -0.10 (0.17)   -0.11 (0.03)**
# 3.1             3-digit                 -0.22 (0.25)     -0.27 (0.13)
#                 4-digit                  0.11 (0.33)      0.14 (0.32)
#
# study                       Goldschlag and Tabarrok Measures  \
# depvar                                          Startup Rate
# RegData Version NAICS Level
# 2.0             3-digit                          0.16 (0.83)
#                 4-digit                         -0.02 (0.89)
# 2.1             3-digit                          3.85 (0.23)
# 2.2             3-digit                          0.20 (0.69)
#                 4-digit                         -0.20 (0.63)
# 3.1             3-digit                          0.41 (0.59)
#                 4-digit                          1.73 (0.23)
#
# study
# depvar                      Job Creation Rate Job Destruction Rate
# RegData Version NAICS Level
# 2.0             3-digit          -0.97 (0.33)         -0.44 (0.51)
#                 4-digit           0.19 (0.36)          0.17 (0.39)
# 2.1             3-digit         5.76 (0.01)**         2.54 (0.06)*
# 2.2             3-digit           0.14 (0.81)          0.41 (0.23)
#                 4-digit          -0.03 (0.95)          0.28 (0.46)
# 3.1             3-digit           1.14 (0.28)          0.42 (0.53)
#                 4-digit           0.78 (0.39)          0.14 (0.84)
